# %% [markdown]
# # Lab 2

# %%
print("Hasnain")
# Out:
# Hasnain

# %% [markdown]
# # **Task 1**

# %%
numbers =[10,23,5,89,45,67,34,22,11,90]
print('orignal list :', numbers)
print('Sum:', sum(numbers))
print('Max:', max(numbers))
print('Min:', min(numbers))
numbers.append(50)
numbers.remove(23)
print ('updated list :', numbers)
# Out:
# orignal list : [10, 23, 5, 89, 45, 67, 34, 22, 11, 90]
# Sum: 396
# Max: 90
# Min: 5
# updated list : [10, 5, 89, 45, 67, 34, 22, 11, 90, 50]

# %% [markdown]
# # **Task 2**

# %%
# create a tuple
fruits =('apple','banana','cherry','orange','kiwi')
print('second element',fruits[1])
print('last element',fruits[-1])
# tuple can't be modified it give an error
fruit_list = list(fruits)
fruit_list[2] = 'orange'
print('Modified list:',fruit_list)
# Out:
# second element banana
# last element kiwi
# Modified list: ['apple', 'banana', 'orange', 'orange', 'kiwi']

# %% [markdown]
# # **Task 3**

# %%
set_a ={1,2,3,4,5}
set_b ={4,5,5,7,8}
print('union:', set_a | set_b)
print('intersection:', set_a & set_b)
print('Difference:', set_a - set_b)
set_a.add(10)
set_b.add(30)

# %% [markdown]
# # **Task 4**

# %%
students = {'ali': 55, 'sara': 66, 'ahmed': 77,'omar': 88,}
print('keys:', students.keys())
print('values:', students.values())
students['Ali']=95
print('updated dictionary:', students)
del students['sara']
print('updated dictionary:', students)
