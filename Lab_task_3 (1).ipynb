# %% [markdown]
# Hasnain khan jadoon  Fa23-bse-035

# %% [markdown]
# Activity 1:

# %%
graph = {
    '5' : ['3', '7'],
    '3' : ['2', '4'],
    '7' : ['8'],
    '2' : [],
    '4' : ['8'],
    '8' : []
}

visited = set()

def dfs(visited, graph, node):
    if node not in visited:
        print(node, end=" ")
        visited.add(node)
        for neighbour in graph[node]:
            dfs(visited, graph, neighbour)

# Driver Code
print("Following is the Depth-First Search")
dfs(visited, graph, '5')
# Out:
# Following is the Depth-First Search
# 5 3 2 4 8 7

# %% [markdown]
# Activity 2:

# %%
from collections import defaultdict

# This class represents a directed graph using adjacency list representation
class Graph:
    # Constructor
    def __init__(self):
        # default dictionary to store graph
        self.graph = defaultdict(list)

    # function to add an edge to graph
    def addEdge(self, u, v):
        self.graph[u].append(v)

    # A function used by DFS
    def DFSUtil(self, v, visited):
        # Mark the current node as visited and print it
        visited[v] = True
        print(v, end=" ")

        # Recur for all the vertices adjacent to this vertex
        for i in self.graph[v]:
            if visited[i] == False:
                self.DFSUtil(i, visited)

    # The function to do DFS traversal. It uses recursive DFSUtil()
    def DFS(self):
        # Calculate the total number of vertices (V)
        # based on the highest node value present
        if not self.graph:
            return
        V = max(max(self.graph.keys()), max([node for sublist in self.graph.values() for node in sublist])) + 1

        # Mark all the vertices as not visited
        visited = [False] * (V)

        # Call the recursive helper function to print DFS traversal
        # starting from all vertices one by one (handles disconnected components)
        for i in range(V):
            if visited[i] == False:
                self.DFSUtil(i, visited)


g = Graph()
g.addEdge(0, 1)
g.addEdge(0, 2)
g.addEdge(1, 2)
g.addEdge(2, 0)
g.addEdge(2, 3)
g.addEdge(3, 3)

print("Following is Depth First Traversal:")
g.DFS()
# Out:
# Following is Depth First Traversal:
# 0 1 2 3

# %% [markdown]
# Graded lab task 1

# %%
def get_graph():

    return {
        'Arad': {'Zerind': 75, 'Sibiu': 140, 'Timisoara': 118},
        'Zerind': {'Arad': 75, 'Oradea': 71},
        'Oradea': {'Zerind': 71, 'Sibiu': 151},
        'Sibiu': {'Arad': 140, 'Oradea': 151, 'Fagaras': 99, 'Rimnicu Vilcea': 80},
        'Timisoara': {'Arad': 118, 'Lugoj': 111},
        'Lugoj': {'Timisoara': 111, 'Mehadia': 70},
        'Mehadia': {'Lugoj': 70, 'Drobeta': 75},
        'Drobeta': {'Mehadia': 75, 'Craiova': 120},
        'Craiova': {'Drobeta': 120, 'Rimnicu Vilcea': 146, 'Pitesti': 138},
        'Rimnicu Vilcea': {'Sibiu': 80, 'Craiova': 146, 'Pitesti': 97},
        'Fagaras': {'Sibiu': 99, 'Bucharest': 211},
        'Pitesti': {'Rimnicu Vilcea': 97, 'Craiova': 138, 'Bucharest': 101},
        'Bucharest': {'Fagaras': 211, 'Pitesti': 101, 'Giurgiu': 90, 'Urziceni': 85},
        'Giurgiu': {'Bucharest': 90},
        'Urziceni': {'Bucharest': 85, 'Vaslui': 142, 'Hirsova': 98},
        'Vaslui': {'Urziceni': 142, 'Iasi': 92},
        'Iasi': {'Vaslui': 92, 'Neamt': 87},
        'Neamt': {'Iasi': 87},
        'Hirsova': {'Urziceni': 98, 'Eforie': 86},
        'Eforie': {'Hirsova': 86}
    }

def dfs_solve(graph, start, goal):
    stack = [(start, [start], 0)]
    visited = set()

    while stack:
        (node, path, cost) = stack.pop()

        if node not in visited:
            if node == goal:
                return path, cost

            visited.add(node)



            for neighbor, weight in sorted(graph[node].items(), reverse=True):
                if neighbor not in visited:
                    stack.append((neighbor, path + [neighbor], cost + weight))

    return None, 0

romania_map = get_graph()
start_city = 'Arad'
end_city = 'Bucharest'

path, total_distance = dfs_solve(romania_map, start_city, end_city)


print(f"Goal Node Reached!")
print(f"Path: {' -> '.join(path)}")
print(f"Total distance to reach the path: {total_distance}")
# Out:
# Goal Node Reached!
# Path: Arad -> Sibiu -> Fagaras -> Bucharest
# Total distance to reach the path: 450

# %% [markdown]
# LAb task 2

# %%
from collections import deque

# Graph represented as an adjacency list of tuples: (neighbor, weight)
graph = {
    'Arad': [('Zerind', 75), ('Sibiu', 140), ('Timisoara', 118)],
    'Zerind': [('Arad', 75), ('Oradea', 71)],
    'Oradea': [('Zerind', 71), ('Sibiu', 151)],
    'Sibiu': [('Arad', 140), ('Oradea', 151), ('Fagaras', 99), ('Rimnicu Vilcea', 80)],
    'Timisoara': [('Arad', 118), ('Lugoj', 111)],
    'Lugoj': [('Timisoara', 111), ('Mehadia', 70)],
    'Mehadia': [('Lugoj', 70), ('Drobeta', 75)],
    'Drobeta': [('Mehadia', 75), ('Craiova', 120)],
    'Craiova': [('Drobeta', 120), ('Rimnicu Vilcea', 146), ('Pitesti', 138)],
    'Rimnicu Vilcea': [('Sibiu', 80), ('Craiova', 146), ('Pitesti', 97)],
    'Fagaras': [('Sibiu', 99), ('Bucharest', 211)],
    'Pitesti': [('Rimnicu Vilcea', 97), ('Craiova', 138), ('Bucharest', 101)],
    'Bucharest': [('Fagaras', 211), ('Pitesti', 101), ('Giurgiu', 90), ('Urziceni', 85)],
    'Giurgiu': [('Bucharest', 90)],
    'Urziceni': [('Bucharest', 85), ('Vaslui', 142), ('Hirsova', 98)],
    'Vaslui': [('Urziceni', 142), ('Iasi', 92)],
    'Iasi': [('Vaslui', 92), ('Neamt', 87)],
    'Neamt': [('Iasi', 87)],
    'Hirsova': [('Urziceni', 98), ('Eforie', 86)],
    'Eforie': [('Hirsova', 86)]
}

def bfs(graph, start, goal):
    queue = deque([(start, [start], 0)])
    visited = set()
    while queue:
        node, path, cost = queue.popleft()
        if node == goal:
            return path, cost, len(visited)
        if node not in visited:
            visited.add(node)
            for neighbor, dist in graph[node]:
                queue.append((neighbor, path + [neighbor], cost + dist))
    return None

def dfs(graph, start, goal):
    stack = [(start, [start], 0)]
    visited = set()
    while stack:
        node, path, cost = stack.pop()
        if node == goal:
            return path, cost, len(visited)
        if node not in visited:
            visited.add(node)
            # Reversing to maintain same exploration order as your image/logic
            for neighbor, dist in reversed(graph[node]):
                if neighbor not in visited:
                    stack.append((neighbor, path + [neighbor], cost + dist))
    return None

# --- Lab Task 2: Comparisons ---

print("--- Case 1: BFS visits fewer nodes than DFS ---")
start, goal = 'Arad', 'Sibiu'
bfs_res = bfs(graph, start, goal)
dfs_res = dfs(graph, start, goal)
print(f"BFS Path: {bfs_res[0]} | Nodes Visited: {bfs_res[2]}")
print(f"DFS Path: {dfs_res[0]} | Nodes Visited: {dfs_res[2]}")

print("\n--- Case 2: BFS visits more nodes than DFS ---")
# To make BFS visit more than DFS, we pick a goal deep in a branch
# that DFS hits early but BFS reaches last.
start, goal = 'Arad', 'Neamt'
bfs_res = bfs(graph, start, goal)
dfs_res = dfs(graph, start, goal)
print(f"BFS Path: {bfs_res[0]} | Nodes Visited: {bfs_res[2]}")
print(f"DFS Path: {dfs_res[0]} | Nodes Visited: {dfs_res[2]}")
# Out:
# --- Case 1: BFS visits fewer nodes than DFS ---
# BFS Path: ['Arad', 'Sibiu'] | Nodes Visited: 2
# DFS Path: ['Arad', 'Zerind', 'Oradea', 'Sibiu'] | Nodes Visited: 3
#
# --- Case 2: BFS visits more nodes than DFS ---
# BFS Path: ['Arad', 'Sibiu', 'Fagaras', 'Bucharest', 'Urziceni', 'Vaslui', 'Iasi', 'Neamt'] | Nodes Visited: 19
# DFS Path: ['Arad', 'Zerind', 'Oradea', 'Sibiu', 'Fagaras', 'Bucharest', 'Urziceni', 'Vaslui', 'Iasi', 'Neamt'] | Nodes Visited: 17
